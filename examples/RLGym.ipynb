# %%
from fishyrl.environments import VectorizedRLGymEnvironment
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776647574.531030    9538 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
envs = VectorizedRLGymEnvironment(num_envs=1, allow_rendering=True)

# %%
envs.obs_shape * 4**2 * 120 * 60**2 / 1024**3
# Out:
# 0.8497238159179688

# %%
obs, _ = envs.reset()

# %%
obs.shape
# Out:
# (1, 4, 132)
